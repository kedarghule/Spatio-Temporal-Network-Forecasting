# %%
import torch
from torch_geometric_temporal.dataset import METRLADatasetLoader
from torch_geometric_temporal.signal import temporal_signal_split

# %%
# Loading dataset

loader = METRLADatasetLoader()

dataset = loader.get_dataset()

train_dataset, test_dataset = temporal_signal_split(dataset, train_ratio = 0.8)
train_dataset, val_dataset = temporal_signal_split(train_dataset, train_ratio=0.8)

# %%
import numpy as np
import pandas as pd
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data

# %%
# class for simple LSTM

class TrafficLSTM(nn.Module):
    def __init__(self, input_size: int, hidden_size:  int, num_layers: int, sequence_len: int):
        super().__init__()
        self.sequence_len = sequence_len
        self.input_size = input_size
        self.lstm = nn.LSTM(input_size = input_size, hidden_size = hidden_size, num_layers = num_layers, batch_first = True, dropout = 0.1)
        # self.linear1 = nn.Linear(hidden_size*sequence_len, int(sequence_len*input_size/2))
        # self.relu1 = nn.ReLU()
        # self.linear2 = nn.Linear(int(sequence_len*input_size/2), sequence_len*input_size)
        self.linear = nn.Linear(hidden_size, input_size)

    def forward(self, x):
        #batch_size = x.shape[0]
        x, _ = self.lstm(x)
        #x = x.reshape(batch_size, -1)
        # #print("LSTM output: ", x.shape)
        # x = self.linear1(x)
        # #print("Linear output: ", x.shape)
        # x = self.relu1(x)
        # x = self.linear2(x)
        # x = x.reshape(batch_size, self.sequence_len, self.input_size)
        #x = x[:, -1, :]
        x = self.linear(x)
        return x

# %%
# we want to take in features and make tensors of each point
# here, we can decide how far out we want to predict
# train will still be an hour of historical data
# test initially contains next 12 timesteps
# choose just one 

def create_dataset(train, test, timestep_to_predict=1):
    train_data_x = np.array(train.features)
    # just get speed
    train_data_x = train_data_x[:,:,0,:]
    N, S, T = train_data_x.shape
    #print(N,S,T)
    #train_data_x = train_data_x.reshape((N, S*T))
    train_data_y = np.array(train.targets)
    #train_data_y = train_data_y[:,:,timestep_to_predict].reshape(N, S, 1)
    #train_data_y = train_data_y.reshape((N, S*T))
    x_train = torch.tensor(train_data_x).swapaxes(1,2)
    y_train = torch.tensor(train_data_y).swapaxes(1,2)
    max_speed = torch.max(x_train)
    print("max: ", max_speed)
    min_speed = torch.min(x_train)
    x_train = (x_train - min_speed)/(max_speed - min_speed)
    y_train = (y_train - min_speed)/(max_speed - min_speed)
    #x_train = torch.tensor(train_data_x)
    #y_train = torch.tensor(train_data_y)
    print(x_train.shape)
    print(y_train.shape)
    return data.TensorDataset(x_train, y_train), max_speed, min_speed

# this will be generic for train/test
def create_dataset(dataset, normalize):
    data_x = np.array(dataset.features)
    # just get speed
    data_x = data_x[:,:,0,:]
    N, S, T = data_x.shape
    #print(N,S,T)
    #train_data_x = train_data_x.reshape((N, S*T))
    data_y = np.array(dataset.targets)
    #train_data_y = train_data_y[:,:,timestep_to_predict].reshape(N, S, 1)
    #train_data_y = train_data_y.reshape((N, S*T))
    
    x = torch.tensor(data_x).swapaxes(1,2)
    y = torch.tensor(data_y).swapaxes(1,2)
    max_speed = torch.max(x)
    #print("max: ", max_speed)
    min_speed = torch.min(x)
    if(normalize == True):
        x = (x - min_speed)/(max_speed - min_speed)
        y = (y - min_speed)/(max_speed - min_speed)
    #x_train = torch.tensor(train_data_x)
    #y_train = torch.tensor(train_data_y)
    print(x.shape)
    print(y.shape)
    return data.TensorDataset(x, y), max_speed, min_speed

# %%
#dataset, max_speed, min_speed = create_dataset(train_dataset, test_dataset)
dataset, max_speed, min_speed = create_dataset(train_dataset, normalize = False)
print("max: ", max_speed)
print("min: ", min_speed)
loader = data.DataLoader(dataset, batch_size = 8, drop_last=True)
#for idx, (data1, label) in enumerate(loader):
#    if idx > 0:
#        break
#    print('label.shape: {}'.format(label.shape))
#    print('label: {}'.format(label))
#    print('data.shape: {}'.format(data1.shape))
# temp = next(iter(loader))
# print(len(temp))
# print(len(temp[0]))
# print(len(temp[0][0]))

val_dataset, max_speed, min_speed = create_dataset(val_dataset, normalize=False)
val_loader = data.DataLoader(val_dataset, batch_size= 8, drop_last=True)
# Out:
# torch.Size([21919, 12, 207])
# torch.Size([21919, 12, 207])
# max:  tensor(0.8115)
# min:  tensor(-2.6522)
# torch.Size([5480, 12, 207])
# torch.Size([5480, 12, 207])

# %%
import time

def train(model, dataloader, loss_func, loss_func_2, device, optimizer):
    model.train()
    total_acc, total_count = 0, 0
    log_interval = 500
    start_time = time.time()
    total_mae = 0
    count = 0
    for idx, (data1, label) in enumerate(dataloader):
        count += 1
        #label = label[:,-1,:]
        label = label.to(device)
        data1 = data1.to(device)
        optimizer.zero_grad()
        
        out = None
        ###########################################################################
        # TODO: compute the logits of the input, get the loss, and do the         #
        # gradient backpropagation.
        ###########################################################################
        # if(idx == 0):
        #    print("input shape: ", data1.shape)
        #    print("label shape: ", label.shape)
        out = model(data1)
        out = out.swapaxes(1,2)
        label = label.swapaxes(1,2)
        
        loss = loss_func(out, label)
        mean = [53.59967, 0.4982691]
        std = [20.209862, 0.28815305]
        # X = X - means.reshape(1, -1, 1)
        # stds = np.std(X, axis=(0, 2))
        # X = X / stds.reshape(1, -1, 1)
        label = label*std[0] + mean[0]
        out = out*std[0] + mean[0]
        # if(idx == 0):
        #     print("output shape, ", out.shape)
        #     print("label shape: ", label.shape)
        #     print("out: ", out[0][0])
        #     print("label: ", label[0][0])
        mae = loss_func_2(out, label).item()
        total_mae += mae
        loss.backward()
        ###########################################################################
        #                             END OF YOUR CODE                            #
        ###########################################################################
        
        optimizer.step()

        
        train_rmse = torch.sqrt(loss)
        if idx % log_interval == 0 and idx > 0:
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches '
                  '| err {:8.3f}'.format(epoch, idx, len(dataloader),
                                              train_rmse))
            total_acc, total_count = 0, 0
            start_time = time.time()
    #print('Total MAE: ', total_mae)
    #print('Total count: ', count)
    return total_mae/count

def evaluate(model, dataloader, loss_func, loss_func_2, device):
    model.eval()
    total_acc, total_count = 0, 0
    
    predictions = []
    labels = []
    total_val_rmse = 0
    total_mae = 0
    count = 0
    with torch.no_grad():
        for idx, (data1, label) in enumerate(dataloader):
            count+=1
            label = label.to(device)
            data1 = data1.to(device)
            # if(idx == 0):
            #     print("input shape: ", data1.shape)
            #     print("label shape: ", label.shape)

            label = label.swapaxes(1,2)
            # undo z-score
            mean = [53.59967, 0.4982691]
            std = [20.209862, 0.28815305]
            # X = X - means.reshape(1, -1, 1)
            # stds = np.std(X, axis=(0, 2))
            # X = X / stds.reshape(1, -1, 1)
            label = label*std[0] + mean[0]
            
            ###########################################################################
            # TODO: compute the logits of the input, get the loss.                    #
            ###########################################################################
            logits = model(data1)
            logits = logits.swapaxes(1,2)
            logits = logits*std[0] + mean[0]
            
            #print(logits.shape)
            #print(label.shape)
            # if(idx == 0):
            #     print("output shape, ", logits.shape)
            #     print("label shape: ", label.shape)
            #     print("out: ", logits[0][0])
            #     print("label: ", label[0][0])
            loss = loss_func(logits, label)
            mae = loss_func_2(logits, label).item()
            ###########################################################################
            #                             END OF YOUR CODE                            #
            ###########################################################################
            val_rmse = torch.sqrt(loss)
            #print("Validation rmse: ", val_rmse)
            #print("Validation mae: ", mae)
            predictions.append(logits.cpu())
            labels.append(label.cpu())
            #predictions.append(logits.item())
            #labels.append(label.item())
            total_val_rmse += val_rmse
            total_mae += mae
    #print('Total MAE: ', total_mae)
    #print('Total count: ', count)
    return predictions, labels, total_val_rmse/count, total_mae/count

# %%
from torch.utils.data.dataset import random_split
import torch.nn.functional as F
#from torchtext.data.functional import to_map_style_dataset

assert torch.cuda.is_available()
# device = 'cuda'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Hyper parameters
epochs = 50 # epoch
lr = 0.000001 # learning rate
input_size = 207
hidden_size = 512

###########################################################################
# TODO: Deinfe the classifier and loss function.
###########################################################################
model = TrafficLSTM(input_size=input_size, hidden_size=hidden_size, num_layers=3, sequence_len=12)
loss_func = F.mse_loss
loss_func2 = F.l1_loss
###########################################################################
#                             END OF YOUR CODE                            #
###########################################################################

# copy the model to the specified device (GPU)
model = model.to(device)
        
optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, epochs, 1e-8)
total_accu = None

train_mae = []
val_mae = []
for epoch in range(1, epochs + 1):
    epoch_start_time = time.time()
    print("TRAINING")
    mae = train(model, loader, loss_func, loss_func2, device, optimizer)
    print("Train MAE: ", mae)
    # need to divide by batch size
    train_mae.append(mae)
    print("VALIDATING")
    pred, lab, rmse, mae = evaluate(model, val_loader, loss_func, loss_func2, device)
    print("Val MAE: ", mae)
    val_mae.append(mae)
    #train(model, loader, loss_func2, device, optimizer)
    #accu_val = evaluate(model, valid_dataloader, loss_func, device)
    # if total_accu is not None and total_accu > accu_val:
    #     scheduler.step()
    # else:
    #     total_accu = accu_val
    # print('-' * 59)
    # print('| end of epoch {:3d} | time: {:5.2f}s | '
    #       'valid accuracy {:8.3f} '.format(epoch,
    #                                        time.time() - epoch_start_time,
    #                                        accu_val))
    # print('-' * 59)
# Out:
# TRAINING
# | epoch   1 |   500/ 2739 batches | err    0.650
# | epoch   1 |  1000/ 2739 batches | err    0.567
# | epoch   1 |  1500/ 2739 batches | err    0.700
# | epoch   1 |  2000/ 2739 batches | err    0.639
# | epoch   1 |  2500/ 2739 batches | err    0.741
# Train MAE:  14.573533219375415
# VALIDATING
# Val MAE:  13.894216575065668
# TRAINING
# | epoch   2 |   500/ 2739 batches | err    0.591
# | epoch   2 |  1000/ 2739 batches | err    0.493
# | epoch   2 |  1500/ 2739 batches | err    0.669
# | epoch   2 |  2000/ 2739 batches | err    0.560
# | epoch   2 |  2500/ 2739 batches | err    0.684
# Train MAE:  12.895484270427993
# VALIDATING
# Val MAE:  12.014471535090982
# TRAINING
# | epoch   3 |   500/ 2739 batches | err    0.531
# | epoch   3 |  1000/ 2739 batches | err    0.445
# | epoch   3 |  1500/ 2739 batches | err    0.668
# | epoch   3 |  2000/ 2739 batches | err    0.549
# | epoch   3 |  2500/ 2739 batches | err    0.670
# Train MAE:  11.920048705153588
# VALIDATING
# Val MAE:  11.638754657411226
# TRAINING
# | epoch   4 |   500/ 2739 batches | err    0.521
# | epoch   4 |  1000/ 2739 batches | err    0.441
# | epoch   4 |  1500/ 2739 batches | err    0.665
# | epoch   4 |  2000/ 2739 batches | err    0.544
# | epoch   4 |  2500/ 2739 batches | err    0.660
# Train MAE:  11.500573090194306
# VALIDATING
# Val MAE:  11.350000350840771
# TRAINING
# | epoch   5 |   500/ 2739 batches | err    0.511
# | epoch   5 |  1000/ 2739 batches | err    0.452
# | epoch   5 |  1500/ 2739 batches | err    0.663
# | epoch   5 |  2000/ 2739 batches | err    0.544
# | epoch   5 |  2500/ 2739 batches | err    0.658
# Train MAE:  11.154534229008375
# VALIDATING
# Val MAE:  11.075742294144456
# TRAINING
# | epoch   6 |   500/ 2739 batches | err    0.501
# | epoch   6 |  1000/ 2739 batches | err    0.462
# | epoch   6 |  1500/ 2739 batches | err    0.663
# | epoch   6 |  2000/ 2739 batches | err    0.544
# | epoch   6 |  2500/ 2739 batches | err    0.659
# Train MAE:  10.846748617366528
# VALIDATING
# Val MAE:  10.836000488448317
# TRAINING
# | epoch   7 |   500/ 2739 batches | err    0.491
# | epoch   7 |  1000/ 2739 batches | err    0.463
# | epoch   7 |  1500/ 2739 batches | err    0.662
# | epoch   7 |  2000/ 2739 batches | err    0.545
# | epoch   7 |  2500/ 2739 batches | err    0.660
# Train MAE:  10.583977043824547
# VALIDATING
# Val MAE:  10.637942655243142
# TRAINING
# | epoch   8 |   500/ 2739 batches | err    0.484
# | epoch   8 |  1000/ 2739 batches | err    0.458
# | epoch   8 |  1500/ 2739 batches | err    0.662
# | epoch   8 |  2000/ 2739 batches | err    0.545
# | epoch   8 |  2500/ 2739 batches | err    0.660
# Train MAE:  10.366423471255127
# VALIDATING
# Val MAE:  10.473919008074015
# TRAINING
# | epoch   9 |   500/ 2739 batches | err    0.477
# | epoch   9 |  1000/ 2739 batches | err    0.451
# | epoch   9 |  1500/ 2739 batches | err    0.662
# | epoch   9 |  2000/ 2739 batches | err    0.544
# | epoch   9 |  2500/ 2739 batches | err    0.661
# Train MAE:  10.185090064654258
# VALIDATING
# Val MAE:  10.335296620417685
# TRAINING
# | epoch  10 |   500/ 2739 batches | err    0.472
# | epoch  10 |  1000/ 2739 batches | err    0.441
# | epoch  10 |  1500/ 2739 batches | err    0.662
# | epoch  10 |  2000/ 2739 batches | err    0.544
# | epoch  10 |  2500/ 2739 batches | err    0.660
# Train MAE:  10.032207877760431
# VALIDATING
# Val MAE:  10.21579076947957
# TRAINING
# | epoch  11 |   500/ 2739 batches | err    0.467
# | epoch  11 |  1000/ 2739 batches | err    0.431
# | epoch  11 |  1500/ 2739 batches | err    0.661
# | epoch  11 |  2000/ 2739 batches | err    0.543
# | epoch  11 |  2500/ 2739 batches | err    0.660
# Train MAE:  9.901006296456579
# VALIDATING
# Val MAE:  10.110223634399636
# TRAINING
# | epoch  12 |   500/ 2739 batches | err    0.464
# | epoch  12 |  1000/ 2739 batches | err    0.422
# | epoch  12 |  1500/ 2739 batches | err    0.661
# | epoch  12 |  2000/ 2739 batches | err    0.542
# | epoch  12 |  2500/ 2739 batches | err    0.659
# Train MAE:  9.78664664153245
# VALIDATING
# Val MAE:  10.014999950019112
# TRAINING
# | epoch  13 |   500/ 2739 batches | err    0.460
# | epoch  13 |  1000/ 2739 batches | err    0.412
# | epoch  13 |  1500/ 2739 batches | err    0.660
# | epoch  13 |  2000/ 2739 batches | err    0.541
# | epoch  13 |  2500/ 2739 batches | err    0.658
# Train MAE:  9.684806493826702
# VALIDATING
# Val MAE:  9.92769030132433
# TRAINING
# | epoch  14 |   500/ 2739 batches | err    0.457
# | epoch  14 |  1000/ 2739 batches | err    0.399
# | epoch  14 |  1500/ 2739 batches | err    0.660
# | epoch  14 |  2000/ 2739 batches | err    0.540
# | epoch  14 |  2500/ 2739 batches | err    0.657
# Train MAE:  9.59172448680191
# VALIDATING
# Val MAE:  9.845229542168388
# TRAINING
# | epoch  15 |   500/ 2739 batches | err    0.455
# | epoch  15 |  1000/ 2739 batches | err    0.390
# | epoch  15 |  1500/ 2739 batches | err    0.659
# | epoch  15 |  2000/ 2739 batches | err    0.539
# | epoch  15 |  2500/ 2739 batches | err    0.656
# Train MAE:  9.503959339001876
# VALIDATING
# Val MAE:  9.766078939229033
# TRAINING
# | epoch  16 |   500/ 2739 batches | err    0.453
# | epoch  16 |  1000/ 2739 batches | err    0.380
# | epoch  16 |  1500/ 2739 batches | err    0.658
# | epoch  16 |  2000/ 2739 batches | err    0.537
# | epoch  16 |  2500/ 2739 batches | err    0.655
# Train MAE:  9.420026406357435
# VALIDATING
# Val MAE:  9.687795579520456
# TRAINING
# | epoch  17 |   500/ 2739 batches | err    0.451
# | epoch  17 |  1000/ 2739 batches | err    0.370
# | epoch  17 |  1500/ 2739 batches | err    0.657
# | epoch  17 |  2000/ 2739 batches | err    0.536
# | epoch  17 |  2500/ 2739 batches | err    0.653
# Train MAE:  9.33690545201171
# VALIDATING
# Val MAE:  9.609813513372936
# TRAINING
# | epoch  18 |   500/ 2739 batches | err    0.449
# | epoch  18 |  1000/ 2739 batches | err    0.359
# | epoch  18 |  1500/ 2739 batches | err    0.655
# | epoch  18 |  2000/ 2739 batches | err    0.535
# | epoch  18 |  2500/ 2739 batches | err    0.651
# Train MAE:  9.254617850246897
# VALIDATING
# Val MAE:  9.531097304559973
# TRAINING
# | epoch  19 |   500/ 2739 batches | err    0.447
# | epoch  19 |  1000/ 2739 batches | err    0.352
# | epoch  19 |  1500/ 2739 batches | err    0.653
# | epoch  19 |  2000/ 2739 batches | err    0.533
# | epoch  19 |  2500/ 2739 batches | err    0.650
# Train MAE:  9.173909930253211
# VALIDATING
# Val MAE:  9.452609924330329
# TRAINING
# | epoch  20 |   500/ 2739 batches | err    0.445
# | epoch  20 |  1000/ 2739 batches | err    0.344
# | epoch  20 |  1500/ 2739 batches | err    0.650
# | epoch  20 |  2000/ 2739 batches | err    0.532
# | epoch  20 |  2500/ 2739 batches | err    0.648
# Train MAE:  9.092928228259913
# VALIDATING
# Val MAE:  9.377631615548239
# TRAINING
# | epoch  21 |   500/ 2739 batches | err    0.444
# | epoch  21 |  1000/ 2739 batches | err    0.336
# | epoch  21 |  1500/ 2739 batches | err    0.647
# | epoch  21 |  2000/ 2739 batches | err    0.530
# | epoch  21 |  2500/ 2739 batches | err    0.647
# Train MAE:  9.01586413505348
# VALIDATING
# Val MAE:  9.30596252044622
# TRAINING
# | epoch  22 |   500/ 2739 batches | err    0.443
# | epoch  22 |  1000/ 2739 batches | err    0.331
# | epoch  22 |  1500/ 2739 batches | err    0.643
# | epoch  22 |  2000/ 2739 batches | err    0.529
# | epoch  22 |  2500/ 2739 batches | err    0.647
# Train MAE:  8.943384179149765
# VALIDATING
# Val MAE:  9.238850894287555
# TRAINING
# | epoch  23 |   500/ 2739 batches | err    0.441
# | epoch  23 |  1000/ 2739 batches | err    0.325
# | epoch  23 |  1500/ 2739 batches | err    0.639
# | epoch  23 |  2000/ 2739 batches | err    0.527
# | epoch  23 |  2500/ 2739 batches | err    0.646
# Train MAE:  8.874624789131083
# VALIDATING
# Val MAE:  9.17804325549272
# TRAINING
# | epoch  24 |   500/ 2739 batches | err    0.440
# | epoch  24 |  1000/ 2739 batches | err    0.324
# | epoch  24 |  1500/ 2739 batches | err    0.635
# | epoch  24 |  2000/ 2739 batches | err    0.526
# | epoch  24 |  2500/ 2739 batches | err    0.644
# Train MAE:  8.81158774923608
# VALIDATING
# Val MAE:  9.122117106583866
# TRAINING
# | epoch  25 |   500/ 2739 batches | err    0.439
# | epoch  25 |  1000/ 2739 batches | err    0.320
# | epoch  25 |  1500/ 2739 batches | err    0.631
# | epoch  25 |  2000/ 2739 batches | err    0.525
# | epoch  25 |  2500/ 2739 batches | err    0.644
# Train MAE:  8.752841562195911
# VALIDATING
# Val MAE:  9.071502550849079
# TRAINING
# | epoch  26 |   500/ 2739 batches | err    0.438
# | epoch  26 |  1000/ 2739 batches | err    0.319
# | epoch  26 |  1500/ 2739 batches | err    0.627
# | epoch  26 |  2000/ 2739 batches | err    0.523
# | epoch  26 |  2500/ 2739 batches | err    0.640
# Train MAE:  8.698754901126946
# VALIDATING
# Val MAE:  9.025446030345277
# TRAINING
# | epoch  27 |   500/ 2739 batches | err    0.437
# | epoch  27 |  1000/ 2739 batches | err    0.315
# | epoch  27 |  1500/ 2739 batches | err    0.624
# | epoch  27 |  2000/ 2739 batches | err    0.523
# | epoch  27 |  2500/ 2739 batches | err    0.637
# Train MAE:  8.6485077975309
# VALIDATING
# Val MAE:  8.983766792116374
# TRAINING
# | epoch  28 |   500/ 2739 batches | err    0.436
# | epoch  28 |  1000/ 2739 batches | err    0.313
# | epoch  28 |  1500/ 2739 batches | err    0.620
# | epoch  28 |  2000/ 2739 batches | err    0.522
# | epoch  28 |  2500/ 2739 batches | err    0.634
# Train MAE:  8.600963346363637
# VALIDATING
# Val MAE:  8.945393565101345
# TRAINING
# | epoch  29 |   500/ 2739 batches | err    0.435
# | epoch  29 |  1000/ 2739 batches | err    0.312
# | epoch  29 |  1500/ 2739 batches | err    0.617
# | epoch  29 |  2000/ 2739 batches | err    0.521
# | epoch  29 |  2500/ 2739 batches | err    0.632
# Train MAE:  8.55772022819728
# VALIDATING
# Val MAE:  8.909219723026247
# TRAINING
# | epoch  30 |   500/ 2739 batches | err    0.435
# | epoch  30 |  1000/ 2739 batches | err    0.311
# | epoch  30 |  1500/ 2739 batches | err    0.614
# | epoch  30 |  2000/ 2739 batches | err    0.519
# | epoch  30 |  2500/ 2739 batches | err    0.630
# Train MAE:  8.515975388961797
# VALIDATING
# Val MAE:  8.876608611197367
# TRAINING
# | epoch  31 |   500/ 2739 batches | err    0.434
# | epoch  31 |  1000/ 2739 batches | err    0.311
# | epoch  31 |  1500/ 2739 batches | err    0.611
# | epoch  31 |  2000/ 2739 batches | err    0.519
# | epoch  31 |  2500/ 2739 batches | err    0.627
# Train MAE:  8.478175725846363
# VALIDATING
# Val MAE:  8.847215990776563
# TRAINING
# | epoch  32 |   500/ 2739 batches | err    0.433
# | epoch  32 |  1000/ 2739 batches | err    0.309
# | epoch  32 |  1500/ 2739 batches | err    0.608
# | epoch  32 |  2000/ 2739 batches | err    0.518
# | epoch  32 |  2500/ 2739 batches | err    0.627
# Train MAE:  8.44188745137591
# VALIDATING
# Val MAE:  8.819965103594926
# TRAINING
# | epoch  33 |   500/ 2739 batches | err    0.433
# | epoch  33 |  1000/ 2739 batches | err    0.308
# | epoch  33 |  1500/ 2739 batches | err    0.605
# | epoch  33 |  2000/ 2739 batches | err    0.517
# | epoch  33 |  2500/ 2739 batches | err    0.626
# Train MAE:  8.4077520986768
# VALIDATING
# Val MAE:  8.795163315404071
# TRAINING
# | epoch  34 |   500/ 2739 batches | err    0.432
# | epoch  34 |  1000/ 2739 batches | err    0.307
# | epoch  34 |  1500/ 2739 batches | err    0.602
# | epoch  34 |  2000/ 2739 batches | err    0.516
# | epoch  34 |  2500/ 2739 batches | err    0.624
# Train MAE:  8.37603741085586
# VALIDATING
# Val MAE:  8.771205569357768
# TRAINING
# | epoch  35 |   500/ 2739 batches | err    0.431
# | epoch  35 |  1000/ 2739 batches | err    0.307
# | epoch  35 |  1500/ 2739 batches | err    0.599
# | epoch  35 |  2000/ 2739 batches | err    0.515
# | epoch  35 |  2500/ 2739 batches | err    0.622
# Train MAE:  8.345862680127386
# VALIDATING
# Val MAE:  8.748962035492388
# TRAINING
# | epoch  36 |   500/ 2739 batches | err    0.431
# | epoch  36 |  1000/ 2739 batches | err    0.307
# | epoch  36 |  1500/ 2739 batches | err    0.599
# | epoch  36 |  2000/ 2739 batches | err    0.515
# | epoch  36 |  2500/ 2739 batches | err    0.621
# Train MAE:  8.317039102392068
# VALIDATING
# Val MAE:  8.72870737757996
# TRAINING
# | epoch  37 |   500/ 2739 batches | err    0.431
# | epoch  37 |  1000/ 2739 batches | err    0.307
# | epoch  37 |  1500/ 2739 batches | err    0.597
# | epoch  37 |  2000/ 2739 batches | err    0.513
# | epoch  37 |  2500/ 2739 batches | err    0.621
# Train MAE:  8.28860668328262
# VALIDATING
# Val MAE:  8.708672002806281
# TRAINING
# | epoch  38 |   500/ 2739 batches | err    0.430
# | epoch  38 |  1000/ 2739 batches | err    0.305
# | epoch  38 |  1500/ 2739 batches | err    0.594
# | epoch  38 |  2000/ 2739 batches | err    0.513
# | epoch  38 |  2500/ 2739 batches | err    0.619
# Train MAE:  8.262229751261014
# VALIDATING
# Val MAE:  8.690108849532413
# TRAINING
# | epoch  39 |   500/ 2739 batches | err    0.429
# | epoch  39 |  1000/ 2739 batches | err    0.305
# | epoch  39 |  1500/ 2739 batches | err    0.593
# | epoch  39 |  2000/ 2739 batches | err    0.513
# | epoch  39 |  2500/ 2739 batches | err    0.618
# Train MAE:  8.237508825334853
# VALIDATING
# Val MAE:  8.672825617685806
# TRAINING
# | epoch  40 |   500/ 2739 batches | err    0.429
# | epoch  40 |  1000/ 2739 batches | err    0.305
# | epoch  40 |  1500/ 2739 batches | err    0.591
# | epoch  40 |  2000/ 2739 batches | err    0.512
# | epoch  40 |  2500/ 2739 batches | err    0.617
# Train MAE:  8.21311054842539
# VALIDATING
# Val MAE:  8.656789913316713
# TRAINING
# | epoch  41 |   500/ 2739 batches | err    0.428
# | epoch  41 |  1000/ 2739 batches | err    0.305
# | epoch  41 |  1500/ 2739 batches | err    0.589
# | epoch  41 |  2000/ 2739 batches | err    0.510
# | epoch  41 |  2500/ 2739 batches | err    0.617
# Train MAE:  8.189730129523971
# VALIDATING
# Val MAE:  8.640782305445985
# TRAINING
# | epoch  42 |   500/ 2739 batches | err    0.429
# | epoch  42 |  1000/ 2739 batches | err    0.305
# | epoch  42 |  1500/ 2739 batches | err    0.587
# | epoch  42 |  2000/ 2739 batches | err    0.510
# | epoch  42 |  2500/ 2739 batches | err    0.616
# Train MAE:  8.167083682784115
# VALIDATING
# Val MAE:  8.625401432496789
# TRAINING
# | epoch  43 |   500/ 2739 batches | err    0.428
# | epoch  43 |  1000/ 2739 batches | err    0.303
# | epoch  43 |  1500/ 2739 batches | err    0.586
# | epoch  43 |  2000/ 2739 batches | err    0.510
# | epoch  43 |  2500/ 2739 batches | err    0.615
# Train MAE:  8.145080538812715
# VALIDATING
# Val MAE:  8.611955686903348
# TRAINING
# | epoch  44 |   500/ 2739 batches | err    0.427
# | epoch  44 |  1000/ 2739 batches | err    0.303
# | epoch  44 |  1500/ 2739 batches | err    0.584
# | epoch  44 |  2000/ 2739 batches | err    0.508
# | epoch  44 |  2500/ 2739 batches | err    0.615
# Train MAE:  8.124437328497395
# VALIDATING
# Val MAE:  8.597457316322048
# TRAINING
# | epoch  45 |   500/ 2739 batches | err    0.427
# | epoch  45 |  1000/ 2739 batches | err    0.303
# | epoch  45 |  1500/ 2739 batches | err    0.584
# | epoch  45 |  2000/ 2739 batches | err    0.508
# | epoch  45 |  2500/ 2739 batches | err    0.614
# Train MAE:  8.10392214060265
# VALIDATING
# Val MAE:  8.585328155364433
# TRAINING
# | epoch  46 |   500/ 2739 batches | err    0.428
# | epoch  46 |  1000/ 2739 batches | err    0.303
# | epoch  46 |  1500/ 2739 batches | err    0.582
# | epoch  46 |  2000/ 2739 batches | err    0.507
# | epoch  46 |  2500/ 2739 batches | err    0.612
# Train MAE:  8.085598019101663
# VALIDATING
# Val MAE:  8.572095883849764
# TRAINING
# | epoch  47 |   500/ 2739 batches | err    0.427
# | epoch  47 |  1000/ 2739 batches | err    0.303
# | epoch  47 |  1500/ 2739 batches | err    0.581
# | epoch  47 |  2000/ 2739 batches | err    0.507
# | epoch  47 |  2500/ 2739 batches | err    0.613
# Train MAE:  8.066005418839442
# VALIDATING
# Val MAE:  8.56099457427533
# TRAINING
# | epoch  48 |   500/ 2739 batches | err    0.427
# | epoch  48 |  1000/ 2739 batches | err    0.301
# | epoch  48 |  1500/ 2739 batches | err    0.580
# | epoch  48 |  2000/ 2739 batches | err    0.505
# | epoch  48 |  2500/ 2739 batches | err    0.613
# Train MAE:  8.048296921442093
# VALIDATING
# Val MAE:  8.549239611103587
# TRAINING
# | epoch  49 |   500/ 2739 batches | err    0.427
# | epoch  49 |  1000/ 2739 batches | err    0.301
# | epoch  49 |  1500/ 2739 batches | err    0.578
# | epoch  49 |  2000/ 2739 batches | err    0.505
# | epoch  49 |  2500/ 2739 batches | err    0.611
# Train MAE:  8.030190665515594
# VALIDATING
# Val MAE:  8.53799590124701
# TRAINING
# | epoch  50 |   500/ 2739 batches | err    0.426
# | epoch  50 |  1000/ 2739 batches | err    0.300
# | epoch  50 |  1500/ 2739 batches | err    0.578
# | epoch  50 |  2000/ 2739 batches | err    0.505
# | epoch  50 |  2500/ 2739 batches | err    0.610
# Train MAE:  8.01216368337494
# VALIDATING
# Val MAE:  8.526375005193

# %%
print(train_mae)
print(val_mae)
# Out:
# [14.573533219375415, 12.895484270427993, 11.920048705153588, 11.500573090194306, 11.154534229008375, 10.846748617366528, 10.583977043824547, 10.366423471255127, 10.185090064654258, 10.032207877760431, 9.901006296456579, 9.78664664153245, 9.684806493826702, 9.59172448680191, 9.503959339001876, 9.420026406357435, 9.33690545201171, 9.254617850246897, 9.173909930253211, 9.092928228259913, 9.01586413505348, 8.943384179149765, 8.874624789131083, 8.81158774923608, 8.752841562195911, 8.698754901126946, 8.6485077975309, 8.600963346363637, 8.55772022819728, 8.515975388961797, 8.478175725846363, 8.44188745137591, 8.4077520986768, 8.37603741085586, 8.345862680127386, 8.317039102392068, 8.28860668328262, 8.262229751261014, 8.237508825334853, 8.21311054842539, 8.189730129523971, 8.167083682784115, 8.145080538812715, 8.124437328497395, 8.10392214060265, 8.085598019101663, 8.066005418839442, 8.048296921442093, 8.030190665515594, 8.01216368337494]
# [13.894216575065668, 12.014471535090982, 11.638754657411226, 11.350000350840771, 11.075742294144456, 10.836000488448317, 10.637942655243142, 10.473919008074015, 10.335296620417685, 10.21579076947957, 10.110223634399636, 10.014999950019112, 9.92769030132433, 9.845229542168388, 9.766078939229033, 9.687795579520456, 9.609813513372936, 9.531097304559973, 9.452609924330329, 9.377631615548239, 9.30596252044622, 9.238850894287555, 9.17804325549272, 9.122117106583866, 9.071502550849079, 9.025446030345277, 8.983766792116374, 8.945393565101345, 8.909219723026247, 8.876608611197367, 8.847215990776563, 8.819965103594926, 8.795163315404071, 8.771205569357768, 8.748962035492388, 8.72870737757996, 8.708672002806281, 8.690108849532413, 8.672825617685806, 8.656789913316713, 8.640782305445985, 8.625401432496789, 8.611955686903348, 8.597457316322048, 8.585328155364433, 8.572095883849764, 8.56099457427533, 8.549239611103587, 8.53799590124701, 8.526375005193]

# %%
torch.save(model, "LSTM_50_epoch")

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(train_mae, label = 'Train')
plt.plot(val_mae, label = 'Validation')
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("MAE")
plt.show()

# %%
dataset, max_speed, min_speed = create_dataset(test_dataset, normalize = False)
print("max: ", max_speed)
print("min: ", min_speed)


test_loader = data.DataLoader(dataset, batch_size = 8, drop_last=True)
for idx, (data1, label) in enumerate(test_loader):
    if idx > 0:
        break
    # print('label.shape: {}'.format(label.shape))
    # print('label: {}'.format(label))
    # print('data.shape: {}'.format(data1.shape))
# Out:
# torch.Size([6850, 12, 207])
# torch.Size([6850, 12, 207])
# max:  tensor(0.8115)
# min:  tensor(-2.6522)

# %%
pred, lab, rmse, mae = evaluate(model, test_loader, loss_func, loss_func2, device)

# %%
print(mae)
# Out:
# 9.608837148296498

# %%
pred = torch.cat(pred)
lab = torch.cat(lab)

# %%
pred = pred.numpy()

# %%
lab = lab.numpy()

# %%
print(pred.shape)
print(lab.shape)
# Out:
# (6848, 207, 12)
# (6848, 207, 12)

# %%
print(pred[2360, 130, :])
print(lab[2360, 130, :])
# Out:
# [48.4391   45.26482  46.891983 48.653145 49.766758 50.23816  50.345234
#  50.883335 51.347263 51.685627 51.920467 52.828297]
# [25.750002 21.857143 27.88889  29.125    41.375    60.625    52.333332
#  34.75     27.125    27.750002 27.5      31.25    ]

# %%
plt.plot(pred[2350:3000, 100, 2], label = 'LSTM Prediction')
plt.plot(lab[2350:3000, 100, 2], label = 'Actual')
plt.legend()
plt.xlabel("Timestep")
plt.ylabel("Speed (MPH)")
plt.show()

# %%
np.save('Results/LSTM/pred.npy', pred)
np.save('Results/LSTM/labels.npy', lab)
